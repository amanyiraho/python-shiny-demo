# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
data = pd.read_fwf("../data/data.tsv")

# %%
data
# Out:
#     Duration  Unnamed: 1   Date  Pulse  Maxpulse       Calories
# 0          0          60  '2020/12/01'       110  130     409.1
# 1          1          60  '2020/12/02'       117  145     479.0
# 2          2          60  '2020/12/03'       103  135     340.0
# 3          3          45  '2020/12/04'       109  175     282.4
# 4          4          45  '2020/12/05'       117  148     406.0
# 5          5          60  '2020/12/06'       102  127     300.0
# 6          6          60  '2020/12/07'       110  136     374.0
# 7          7         450  '2020/12/08'       104  134     253.3
# 8          8          30  '2020/12/09'       109  133     195.1
# 9          9          60  '2020/12/10'        98  124     269.0
# 10        10          60  '2020/12/11'       103  147     329.3
# 11        11          60  '2020/12/12'       100  120     250.7
# 12        12          60  '2020/12/12'       100  120     250.7
# 13        13          60  '2020/12/13'       106  128     345.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Duration     32 non-null     int64
#  1   Unnamed: 1   32 non-null     int64
#  2   Date  Pulse  31 non-null     object
#  3   Maxpulse     32 non-null     int64
#  4   Calories     32 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 1.4+ KB

# %%
data.dropna()
# Out:
#     Duration  Unnamed: 1   Date  Pulse  Maxpulse       Calories
# 0          0          60  '2020/12/01'       110  130     409.1
# 1          1          60  '2020/12/02'       117  145     479.0
# 2          2          60  '2020/12/03'       103  135     340.0
# 3          3          45  '2020/12/04'       109  175     282.4
# 4          4          45  '2020/12/05'       117  148     406.0
# 5          5          60  '2020/12/06'       102  127     300.0
# 6          6          60  '2020/12/07'       110  136     374.0
# 7          7         450  '2020/12/08'       104  134     253.3
# 8          8          30  '2020/12/09'       109  133     195.1
# 9          9          60  '2020/12/10'        98  124     269.0
# 10        10          60  '2020/12/11'       103  147     329.3
# 11        11          60  '2020/12/12'       100  120     250.7
# 12        12          60  '2020/12/12'       100  120     250.7
# 13        13          60  '2020/12/13'       106  128     345.3
# ...

# %%
data["Date  Pulse"].fillna("Robinson")
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18    '2020/12/18'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22        Robinson
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26      2020/12/26
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date  Pulse, dtype: object

# %%
max_mean = data["Maxpulse"].mode()[0]
max_mean
# Out:
# 100

# %%
data["Maxpulse"].fillna(max_mean)
# Out:
# 0     110
# 1     117
# 2     103
# 3     109
# 4     117
# 5     102
# 6     110
# 7     104
# 8     109
# 9      98
# 10    103
# 11    100
# 12    100
# 13    106
# 14    104
# 15     98
# 16     98
# 17    100
# 18     90
# 19    103
# 20     97
# 21    108
# 22    100
# 23    130
# 24    105
# 25    102
# 26    100
# 27     92
# 28    103
# 29    100
# 30    102
# 31     92
# Name: Maxpulse, dtype: int64

# %%
data["Date  Pulse"] =  pd.to_datetime(data["Date  Pulse"])

# %%
data = data[["Unnamed: 1",	"Date  Pulse",	"Maxpulse",	"Calories"]]
print(data.head(2))
# Out:
#    Unnamed: 1 Date  Pulse  Maxpulse       Calories
# 0          60  2020-12-01       110  130     409.1
# 1          60  2020-12-02       117  145     479.0

# %%
data=data.rename(columns={"Unnamed: 1":"Duration", "Date  Pulse":"Date"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     datetime64[ns]
#  2   Maxpulse  32 non-null     int64
#  3   Calories  32 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 1.1+ KB

# %%
data.loc[ data["Duration"] == 450, "Duration"] = 45

# %%
data.drop(data.loc[ data["Duration"] == 60].index )
# Out:
#     Duration       Date  Maxpulse       Calories
# 3         45 2020-12-04       109  175     282.4
# 4         45 2020-12-05       117  148     406.0
# 7         45 2020-12-08       104  134     253.3
# 8         30 2020-12-09       109  133     195.1
# 18        45 2020-12-18        90  112       NaN
# 20        45 2020-12-20        97  125     243.0
# 22        45        NaT       100  119     282.0
# 24        45 2020-12-24       105  132     246.0

# %%
data.loc[ data["Duration"] == 30, "Duration"].index
# Out:
# Int64Index([8], dtype='int64')

# %%
data.loc[data.duplicated()]
# Out:
#     Duration       Date  Maxpulse       Calories
# 12        60 2020-12-12       100  120     250.7

# %%
data.drop_duplicates()
# Out:
#     Duration       Date  Maxpulse       Calories
# 0         60 2020-12-01       110  130     409.1
# 1         60 2020-12-02       117  145     479.0
# 2         60 2020-12-03       103  135     340.0
# 3         45 2020-12-04       109  175     282.4
# 4         45 2020-12-05       117  148     406.0
# 5         60 2020-12-06       102  127     300.0
# 6         60 2020-12-07       110  136     374.0
# 7         45 2020-12-08       104  134     253.3
# 8         30 2020-12-09       109  133     195.1
# 9         60 2020-12-10        98  124     269.0
# 10        60 2020-12-11       103  147     329.3
# 11        60 2020-12-12       100  120     250.7
# 13        60 2020-12-13       106  128     345.3
# 14        60 2020-12-14       104  132     379.3
# 15        60 2020-12-15        98  123     275.0
# 16        60 2020-12-16        98  120     215.2
# 17        60 2020-12-17       100  120     300.0
# 18        45 2020-12-18        90  112       NaN
# ...

# %%
data.corr()
# Out:
#           Duration  Maxpulse
# Duration  1.000000 -0.066974
# Maxpulse -0.066974  1.000000

# %%
data.plot(x = "Maxpulse", y = "Calories",kind = "scatter")
plt.show()
# Out:
# <AxesSubplot:xlabel='Maxpulse', ylabel='Calories'>

# %%
data["Duration"].plot(kind = "hist")
plt.show()
