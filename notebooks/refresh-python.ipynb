# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
seal = pd.read_csv("https://github.com/tidyverse/ggplot2/blob/main/data-raw/seals.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Volumes/Robinson/python-projects/python-shiny-demo/notebooks/refresh-python.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Volumes/Robinson/python-projects/python-shiny-demo/notebooks/refresh-python.ipynb#Y142sZmlsZQ%3D%3D?line=0'>1</a> seal = pd.read_csv("https://github.com/tidyverse/ggplot2/blob/main/data-raw/seals.csv")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
air_pollution = pd.read_csv("/Volumes/Robinson/python-projects/python-shiny-demo/data/air_pollution.csv")

# %%
air_pollution.head(10)
# Out:
#   Country  Year  PM2.5_air_pollution      Deaths
# 0   Benin  1990            40.220135  269.191476
# 1   Benin  1995            38.078472  253.049072
# 2   Benin  2000            39.776295  239.987277
# 3   Benin  2005            34.328808  220.332573
# 4   Benin  2010            32.392971  209.059426
# 5   Benin  2011            32.580845  207.493432
# 6   Benin  2012            31.992001  205.939808
# 7   Benin  2013            31.443298  203.058613
# 8   Benin  2014            29.660456  198.612457
# 9   Benin  2015            40.470684  197.503037

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...
